# %%
import os
import networkx as nx 
import matplotlib.pyplot as plt
import pandas as pd
import community

os.getcwd()
# Out:
# 'D:\\home\\adriana\\GitHub\\social_interaction\\clustering'

# %% [markdown]
# # Setting Up The Edgelist
#
# We read in the complete data of who follows whom and store this in the edgelist.

# %%
friendship = nx.read_edgelist('followers_complete.csv',
                                    delimiter = ',', 
                                    create_using = nx.Graph, 
                                    nodetype = str,
                                    data = ("person","retweet_count")
                             )

# %%
# We also need to know who is in this list
 
beteiligte = pd.read_csv('followers_complete.csv', header = None)
beteiligte
# Out:
#                     0               1
# 0     realDonaldTrump        LouDobbs
# 1     realDonaldTrump       GOPLeader
# 2     realDonaldTrump    senatemajldr
# 3     realDonaldTrump      Jim_Jordan
# 4     realDonaldTrump  MariaBartiromo
# ...               ...             ...
# 4597    ChuckGrassley        LouDobbs
# 4598    ChuckGrassley        HouseGOP
# 4599    ChuckGrassley    GOPoversight
# 4600    ChuckGrassley       SenateGOP
# 4601    ChuckGrassley             GOP
#
# [4602 rows x 2 columns]

# %%
beteiligtenliste = []

for name in beteiligte[0]:
    if name not in beteiligtenliste:
        beteiligtenliste.append(name)
        
print(len(beteiligtenliste))
# Out:
# 97

# %% [markdown]
# We thus have 97 praticipants in our dataframe of who follows whom. We need to crosscheck this for our nubers of retweets.

# %%
retweeters = pd.read_csv("../get_retweets/number_of_retweets.csv")
retweeters["0"] = retweeters["0"].str.replace("\@", "")

retweeters
# Out:
#                   0    1
# 0   realDonaldTrump  918
# 1        WhiteHouse  655
# 2         TeamTrump  273
# 3     GOPChairwoman  211
# 4        DanScavino  145
# ..              ...  ...
# 95    SenRonJohnson   15
# 96    SenThomTillis   15
# 97    EliseStefanik   15
# 98         brithume   15
# 99    ChuckGrassley   15
#
# [100 rows x 2 columns]

# %% [markdown]
# We see here that the frames are not of same length. The following accounts are not included:

# %%
to_be_deleted = []

for name in retweeters["0"]:
    if name not in beteiligtenliste:
        to_be_deleted.append(name)
        
to_be_deleted
# Out:
# ['paulsperry_', 'mike_pence', 'DRUDGE_REPORT']

# %% [markdown]
# We are going to delete these accounts from the retweeters-Dataframe (as they are not in the Beteiligtenliste which bases on the entire "who follows whom".

# %%
retweeters.rename(columns = {"0": "user"}, inplace = True)


for element in to_be_deleted:
    retweeters = retweeters[retweeters.user != element]
    
print("This dataframe has now a length of " + str(len(retweeters)))
# Out:
# This dataframe has now a length of 97

# %% [markdown]
# # Drawing the network

# %%
plt.figure(figsize=(10,10))
nx.draw(friendship, with_labels = True, node_size = retweeters["1"], edge_color="black", alpha=0.4)

# %% [markdown]
# # Clustering
#
# ## Partitioning
# First off, we let the algorithm decide how to split our network

# %%
coords = nx.spring_layout(friendship)
automated_partition = community.best_partition(friendship)

print(automated_partition)
# Out:
# {'realDonaldTrump': 0, 'LouDobbs': 1, 'GOPLeader': 1, 'senatemajldr': 1, 'Jim_Jordan': 1, 'MariaBartiromo': 0, 'VP': 1, 'GOPChairwoman': 2, 'parscale': 2, 'PressSec': 1, 'JesseBWatters': 2, 'WhiteHouse': 1, 'Scavino45': 1, 'KellyannePolls': 2, 'IngrahamAngle': 0, 'Mike_Pence': 1, 'TeamTrump': 2, 'seanhannity': 2, 'CLewandowski_': 2, 'KatrinaPierson': 2, 'foxandfriends': 1, 'GeraldoRivera': 2, 'ericbolling': 2, 'DanScavino': 2, 'EricTrump': 2, 'DonaldJTrumpJr': 2, 'IvankaTrump': 1, 'FLOTUS': 1, 'RudyGiuliani': 2, 'DevinNunes': 0, 'charliekirk11': 2, 'LindseyGrahamSC': 1, 'JackPosobiec': 2, 'JennaEllisEsq': 0, 'EliseStefanik': 1, 'RNCResearch': 2, 'TrumpWarRoom': 2, 'marcorubio': 1, 'TimMurtaugh': 2, 'kayleighmcenany': 2, 'GOP': 1, 'OANN': 2, 'HawleyMO': 0, 'RepLeeZeldin': 1, 'RepDougCollins': 1, 'NRA': 2, 'RepMattGaetz': 1, 'KimStrassel': 0, 'thejtlewis': 2, 'GreggJarrett': 2, 'TomFitton': 1, 'MZHemingway': 0, 'dbongino': 0, 'SaraCarterDC': 1, 'dcexaminer': 1, 'DailyCaller': 2, 'ChuckGrassley': 1, 'SenThomTillis': 1, 'RealJamesWoods': 2, 'SenRonJohnson': 1, 'MarshaBlackburn': 1, 'SteveScalise': 1, 'Varneyco': 2, 'marklevinshow': 2, 'SenTomCotton': 1, 'RichardGrenell': 0, 'hughhewitt': 0, 'brithume': 0, 'HouseGOP': 1, 'SenateGOP': 1, 'FoxNews': 1, 'JudicialWatch': 0, 'BreitbartNews': 2, 'SenTedCruz': 1, 'tedcruz': 0, 'RandPaul': 1, 'thehill': 1, 'BuckSexton': 0, 'PollWatch2020': 0, 'thebradfordfile': 0, 'seanmdav': 0, 'RepAndyBiggsAZ': 1, 'RepMarkMeadows': 1, 'DavidJHarrisJr': 2, 'TVNewsHQ': 2, 'ByronYork': 0, 'bennyjohnson': 0, 'SenJohnBarrasso': 1, 'jsolomonReports': 0, 'GOPoversight': 1, 'CDCgov': 1, 'NHC_Atlantic': 1, 'fema': 1, 'AndrewCMcCarthy': 0, 'TheRightMelissa': 2, 'JohnWHuber': 0, 'Lrihendry': 2}

# %%
plt.figure(figsize=(20,17))
nx.draw(friendship,
              pos = coords,
              node_color = list(dict.values(automated_partition)), with_labels = True, alpha = 0.4, 
        edge_color="grey")

# %% [markdown]
# # Comparison
#
# In order to compare this, we also set up a manual categorization.

# %%
manuelle_klas = pd.read_csv("klassifizierung _numbered.csv", header = None)
manuelle_klas[2] = manuelle_klas[2].str.replace("politician", "1")
manuelle_klas[2] = manuelle_klas[2].str.replace("political_org", "2")
manuelle_klas[2] = manuelle_klas[2].str.replace("administration", "3")
manuelle_klas[2] = manuelle_klas[2].str.replace("neus", "4")
manuelle_klas[2] = manuelle_klas[2].str.replace("news", "4")
manuelle_klas[2] = manuelle_klas[2].str.replace("private", "5")
manuelle_klas[2] = manuelle_klas[2].str.replace("family", "6")
manuelle_klas
# Out:
#       0                1  2
# 0     1  realDonaldTrump  1
# 1     2       WhiteHouse  2
# 2     3        TeamTrump  2
# 3     4    GOPChairwoman  1
# 4     5       DanScavino  5
# ..  ...              ... ..
# 95   96    SenRonJohnson  1
# 96   97    SenThomTillis  1
# 97   98    EliseStefanik  1
# 98   99         brithume  4
# 99  100    ChuckGrassley  1
#
# [100 rows x 3 columns]

# %%
for name in manuelle_klas[1]:
    if name not in beteiligtenliste:
        print(name)
        
manuelle_klas.rename(columns = {1: "user"}, inplace = True)
        
for element in to_be_deleted:
    manuelle_klas = manuelle_klas[manuelle_klas.user != element]
# Out:
# paulsperry_
# mike_pence
# DRUDGE_REPORT

# %%
manuelle_klas
# Out:
#       0             user  2
# 0     1  realDonaldTrump  1
# 1     2       WhiteHouse  2
# 2     3        TeamTrump  2
# 3     4    GOPChairwoman  1
# 4     5       DanScavino  5
# ..  ...              ... ..
# 95   96    SenRonJohnson  1
# 96   97    SenThomTillis  1
# 97   98    EliseStefanik  1
# 98   99         brithume  4
# 99  100    ChuckGrassley  1
#
# [97 rows x 3 columns]

# %%
manuelle_klas[2] = pd.to_numeric(manuelle_klas[2])
manuelle_klas
# Out:
#       0             user    2
# 0     1  realDonaldTrump  1.0
# 1     2       WhiteHouse  2.0
# 2     3        TeamTrump  2.0
# 3     4    GOPChairwoman  1.0
# 4     5       DanScavino  5.0
# ..  ...              ...  ...
# 95   96    SenRonJohnson  1.0
# 96   97    SenThomTillis  1.0
# 97   98    EliseStefanik  1.0
# 98   99         brithume  4.0
# 99  100    ChuckGrassley  1.0
#
# [97 rows x 3 columns]

# %% [markdown]
# We now have to turn this into a list into a dictionary to enable the plotting.

# %%
# list
user = manuelle_klas["user"].tolist()
rating = manuelle_klas[2].tolist()

#dict
our_class = dict(zip(user, rating))
our_class
# Out:
# {'realDonaldTrump': 1.0,
#  'WhiteHouse': 2.0,
#  'TeamTrump': 2.0,
#  'GOPChairwoman': 1.0,
#  'DanScavino': 5.0,
#  'Jim_Jordan': 1.0,
#  'GOP': 2.0,
#  'Scavino45': 3.0,
#  'DonaldJTrumpJr': 6.0,
#  'IvankaTrump': 6.0,
#  'GreggJarrett': 4.0,
#  'EricTrump': 6.0,
#  'TomFitton': 5.0,
#  'RepMarkMeadows': 1.0,
#  'marklevinshow': 5.0,
#  'TrumpWarRoom': 2.0,
#  'LindseyGrahamSC': 1.0,
#  'charliekirk11': 5.0,
#  'dbongino': 5.0,
#  'SenateGOP': 1.0,
#  'GOPLeader': 1.0,
#  'JudicialWatch': 2.0,
#  'senatemajldr': 1.0,
#  'foxandfriends': 4.0,
#  'seanhannity': 4.0,
#  'VP': 3.0,
#  'SteveScalise': 1.0,
#  'MZHemingway': 4.0,
#  'FLOTUS': 3.0,
#  'LouDobbs': 4.0,
#  'DailyCaller': 4.0,
#  'BuckSexton': 5.0,
#  'RepAndyBiggsAZ': 1.0,
#  'RepLeeZeldin': 1.0,
#  'KimStrassel': 4.0,
#  'Mike_Pence': 5.0,
#  'MariaBartiromo': 4.0,
#  'PressSec': 3.0,
#  'SaraCarterDC': 4.0,
#  'RepDougCollins': 1.0,
#  'RepMattGaetz': 1.0,
#  'NHC_Atlantic': 2.0,
#  'JohnWHuber': 3.0,
#  'MarshaBlackburn': 1.0,
#  'AndrewCMcCarthy': 4.0,
#  'RandPaul': 1.0,
#  'IngrahamAngle': 4.0,
#  'TVNewsHQ': 5.0,
#  'jsolomonReports': 4.0,
#  'CLewandowski_': 3.0,
#  'parscale': 5.0,
#  'GOPoversight': 2.0,
#  'ByronYork': 4.0,
#  'FoxNews': 4.0,
#  'GeraldoRivera': 5.0,
#  'DevinNunes': 5.0,
#  'BreitbartNews': 4.0,
#  'SenTomCotton': 1.0,
#  'dcexaminer': 4.0,
#  'thebradfordfile': 5.0,
#  'RNCResearch': 2.0,
#  'seanmdav': 5.0,
#  'JackPosobiec': 5.0,
#  'CDCgov': 3.0,
#  'marcorubio': nan,
#  'Lrihendry': 3.0,
#  'SenTedCruz': 1.0,
#  'thehill': 4.0,
#  'PollWatch2020': 5.0,
#  'OANN': 4.0,
#  'DavidJHarrisJr': 5.0,
#  'JennaEllisEsq': 3.0,
#  'NRA': 2.0,
#  'Varneyco': 4.0,
#  'kayleighmcenany': 3.0,
#  'RudyGiuliani': 3.0,
#  'hughhewitt': 4.0,
#  'JesseBWatters': 4.0,
#  'HouseGOP': 2.0,
#  'RealJamesWoods': 5.0,
#  'fema': 2.0,
#  'KatrinaPierson': 3.0,
#  'SenJohnBarrasso': 1.0,
#  'ericbolling': 4.0,
#  'HawleyMO': 1.0,
#  'thejtlewis': 1.0,
#  'TimMurtaugh': 3.0,
#  'RichardGrenell': 3.0,
#  'tedcruz': 5.0,
#  'bennyjohnson': 4.0,
#  'TheRightMelissa': 5.0,
#  'KellyannePolls': 3.0,
#  'SenRonJohnson': 1.0,
#  'SenThomTillis': 1.0,
#  'EliseStefanik': 1.0,
#  'brithume': 4.0,
#  'ChuckGrassley': 1.0}

# %% [markdown]
# We now plot this again.

# %%
plt.figure(figsize=(20,17))
nx.draw(friendship,
              pos = coords,
              node_color = list(dict.values(our_class)), with_labels = True, alpha = 0.4, 
        edge_color="grey")
